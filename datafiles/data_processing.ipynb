# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"data.csv")

df_test = pd.read_csv(r"data2.csv")

print(df_test.head())
# Out:
#    bot_id  mice_type  steps  alpha
# 0       2          2    124   0.08
# 1       2          2    364   0.08
# 2       2          2    330   0.08
# 3       2          2     54   0.08
# 4       2          2    266   0.08

# %%
df.describe(), df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50916 entries, 0 to 50915
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   bot_id     50916 non-null  int64
#  1   mice_type  50916 non-null  int64
#  2   steps      50916 non-null  int64
#  3   alpha      50916 non-null  float64
# dtypes: float64(1), int64(3)
# memory usage: 1.6 MB
# (             bot_id     mice_type         steps         alpha
#  count  50916.000000  50916.000000  50916.000000  50916.000000
#  mean       2.000452      1.810845    310.980379      0.090266
#  std        0.732691      0.391635    237.555780      0.039142
#  min        1.000000      1.000000      0.000000      0.030000
#  25%        1.000000      2.000000    160.000000      0.060000
#  50%        2.000000      2.000000    258.000000      0.080000
#  75%        3.000000      2.000000    397.000000      0.110000
#  max        3.000000      2.000000  12204.000000      0.200000,
#  None)

# %%
df2 = df[df['mice_type']==1]
temp = df2.groupby(['bot_id', 'alpha'])['steps'].mean().reset_index()

plt.figure(figsize=(12, 8))

# line plot for each robot type
sns.lineplot(data=temp, x='alpha', y='steps', hue='bot_id', marker='o')
plt.title('One Stationary Mouse')
plt.xlabel('Alpha')
plt.ylabel('Steps')
plt.legend(title='Robot Type')

plt.show()

# %%
df3 = df[df['mice_type']==2]
temp2 = df3.groupby(['bot_id', 'alpha'])['steps'].mean().reset_index()

plt.figure(figsize=(12, 8))

# line plot for each robot type
sns.lineplot(data=temp2, x='alpha', y='steps', hue='bot_id', marker='o')
plt.title('One Stochastic Mouse')
plt.xlabel('Alpha')
plt.ylabel('Steps')
plt.legend(title='Robot Type')

plt.show()

# %%
# df_test_stationary = df_test[df_test['mice_type']==2]

# temp2 = df_test_stationary.groupby(['bot_id', 'alpha'])['steps'].mean().reset_index()
# plt.figure(figsize=(12, 8))

# # line plot for each robot type
# sns.lineplot(data=temp2, x='alpha', y='steps', hue='bot_id', marker='o')
# plt.title('Bot 3 Testing - One stationary')
# plt.xlabel('Fire Spread Probability (q)')
# plt.ylabel('Success Rate')
# plt.legend(title='Robot Type')

# plt.show()

# %%
# df3 = df[df['mice_type']==2]
# temp2 = df3.groupby(['bot_id', 'alpha'])['steps'].mean().reset_index()

# plt.figure(figsize=(12, 8))

# # line plot for each robot type
# sns.lineplot(data=temp2, x='alpha', y='steps', hue='bot_id', marker='o')
# plt.title('One Stochastic Mouse')
# plt.xlabel('Alpha')
# plt.ylabel('Steps')
# plt.legend(title='Robot Type')

# plt.show()
df_test = pd.read_csv(r"data2.csv")

print(df_test[df_test['bot_id']==3].mean())

df_test_stochastic = df_test[df_test['mice_type']==2]
temp3 = df_test_stochastic.groupby(['bot_id', 'alpha'])['steps'].mean().reset_index()
plt.figure(figsize=(12, 8))

# line plot for each robot type
sns.lineplot(data=temp3, x='alpha', y='steps', hue='bot_id', marker='o')
plt.title('Stochastic 1 mouse TEST BOT 3')
plt.xlabel('Fire Spread Probability (q)')
plt.ylabel('Success Rate')
plt.legend(title='Robot Type')
# Out:
# bot_id         3.000000
# mice_type      2.000000
# steps        279.544304
# alpha          0.073228
# dtype: float64

# %%
print(df_test_stochastic[df_test_stochastic['bot_id']==3].count())
#print(df[df['bot_id']==2].groupby('alpha').count())
grouped_std_dev = df.groupby(['mice_type', 'bot_id'])['steps'].std()
print(grouped_std_dev)
# Out:
# bot_id       632
# mice_type    632
# steps        632
# alpha        632
# dtype: int64
# mice_type  bot_id
# 1          1         300.964332
#            2         247.293996
# 2          1         321.736046
#            2         186.466081
#            3         184.943503
# Name: steps, dtype: float64

# %%
# import csv

# def delete_rows_with_bot_id_3(file_path):
#     # Read the CSV file
#     with open(file_path, mode='r', newline='') as infile:
#         reader = csv.reader(infile)
#         header = next(reader)  # Save the header row
#         rows = [row for row in reader if len(row) == 4 and row[0] != '3']  # Filter out rows where bot_id is 3 and check for proper row length

#     # Write back the filtered data to the CSV file
#     with open(file_path, mode='w', newline='') as outfile:
#         writer = csv.writer(outfile)
#         writer.writerow(header)  # Write the header row
#         writer.writerows(rows)    # Write the filtered rows

# # Example usage
# csv_file_path = r'C:\Users\vsh00\OneDrive - Rutgers University\python\AI\datafiles\data2.csv'
# delete_rows_with_bot_id_3(csv_file_path)
